# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings("ignore")

# %%
url="https://traveltriangle.com/tour-packages/kerala?"

# %%
print(url)
# Out:
# https://traveltriangle.com/tour-packages/kerala?

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
pagecontent=response.text

# %%
# soup=BeautifulSoup(pagecontent)
# soup

# %%
name = []

for x in soup.find_all("p", attrs={"class":"col-md-12 pl0 fw9 m0 f16 pfc3 at_packageName"}):
    names.append(x.text.strip() if x else np.nan)

for name in names:
    print(name)
# Out:
# Alleppey-Munnar Kerala Weekend Tour
# Charismatic Kochi Tour Package
# Hills & Houseboat: Munnar and Alleppey Honeymoon Package
# Vibrant Kochi Munnar Honeymoon Tour Package
# Mesmerizing Getaway To Kochi
# Kerala Wayanad Weekend Holiday
# Trip To Mesmerising Munnar
# Best Selling Kerala Honeymoon Tour Package
# Catch The Beauty Of The Setting Sun In Alleppey
# Best Selling Kerala Houseboat & Jungle Safari Tour Package
# Charming Alleppey Honeymoon Package
# A Blissful Tour In Munnar
# Top 5 Nights 6 Days Kerala Family Tour Packages For A Refreshing Getaway
# Exploring Godâs Own Country, Kerala
# Reasonable Munnar Thekkady Alleppey Honeymoon Packages
# Ecstatic Athirapally Tour Package
# Mesmerizing Kerala Holiday: Weekend in Munnar & Thekkady
# Captivating Thekkady Honeymoon Package
# A Surreal Escape To Mesmerising Destinations
# Visit Kerala And See Astounding Places

# %%
stay = []

for x in soup.find_all("span", attrs={"class":"iblock sfc6"}):
    stay.append(x.text.strip() if x else np.nan)

for s in stay:
    print(s)
# Out:
# 4 Days & 3 Nights
# 4 Days & 3 Nights
# 6 Days & 5 Nights
# 4 Days & 3 Nights
# 2 Days & 1 Nights
# 3 Days & 2 Nights
# 4 Days & 3 Nights
# 5 Days & 4 Nights
# 2 Days & 1 Nights
# 5 Days & 4 Nights
# 3 Days & 2 Nights
# 3 Days & 2 Nights
# 6 Days & 5 Nights
# 3 Days & 2 Nights
# 4 Days & 3 Nights
# 8 Days & 7 Nights
# 4 Days & 3 Nights
# 5 Days & 4 Nights
# 4 Days & 3 Nights
# 4 Days & 3 Nights

# %%
location = []

for x in soup.find_all("ul", attrs={"class":"clearfix package-cities-list at_packagecity_list"}):
    location.append(x.text.strip() if x else np.nan)

for l in location:
    print(l)
# Out:
# Munnar (2D)Alleppey (2D)
# Kochi (1D)Munnar (3D)
# Munnar (2D)Thekkady (1D)Alleppey (1D)Kochi (2D)
# Cochin (1D)Munnar (3D)
# Kochi (2D)
# Wayanad (3D)
# Munnar (2D)Alleppey (2D)
# Munnar (2D)Thekkady (1D)Alleppey (2D)
# Alleppey (2D)
# Munnar (2D)Thekkady (1D)Alleppey (2D)
# Alleppey (3D)
# Munnar (3D)
# Munnar (2D)Thekkady (1D)Alleppey (1D)Kochi (2D)
# Munnar (1D)Alleppey (2D)
# Munnar (1D)Thekkady (1D)Alleppey (2D)
# Athirapally (2D)Munnar (2D)Alleppey (1D)Kovalam (1D)Trivandrum (2D)
# Munnar (2D)Thekkady (2D)
# Kumarakom (1D)Thekkady (1D)Munnar (3D)
# Munnar (2D)Alleppey (2D)
# Munnar (1D)Thekkady (1D)Kochi (2D)

# %%
discount = []

for x in soup.find_all("span", attrs={"class":"f12 fw4 pt2 pb2 pl8 pr8 radius20 pbc1 sfcw at_discount_label"}):
    discount.append(x.text.strip() if x else np.nan)

for d in discount:
    print(d)
# Out:
# 24% Off
# 9% Off
# 10% Off
# 10% Off
# 9% Off
# 5% Off
# 9% Off
# 28% Off
# 9% Off
# 19% Off
# 9% Off
# 9% Off
# 18% Off
# 10% Off
# 12% Off
# 9% Off
# 29% Off
# 10% Off
# 21% Off
# 11% Off

# %%
tags = []

for x in soup.find_all("ul", attrs={"class":"package-tags at_package_tags"}):
    tags.append(x.text.strip() if x else np.nan)

for t in tags:
    print(t)
# Out:
# Spice PlantationsHill stationHouseboat StayCruisesEcho PointAdventureTea MuseumNatureBest sellersWaterfallBudget
# WaterfallsAdventureNatureShoppingWildlifeCulturalBudget
# Periyar Wildlife SanctuaryCruisesEravikulam National ParkHill stationJungle SafariNatureBackwatersWaterfallWildlifeRomanticBudget
# Scenic viewsAdventureTea gardensHill stationMarine DriveNatureWildlifeRomanticFORESTBudget
# ScenerylandscapeSightseeingLeisure TimeNatureAdventureHistoricalBudget
# NatureWaterfallHillsWeekend GetawayHill stationAdventureSightseeingBudget
# Scenic viewsHill stationTea plantationsShoppingNatureWaterfallWildlifeBudget
# Houseboat StayAdventureJeep SafariHill stationCruisesRomanticNatureWildlifeBest sellersWaterfall
# Cruise along the backwaters AdventureLeisure DayCruisesHouseboat StaySightseeingBudget
# Best SellingPrivate CabWildlife safariBackwatersHills
# AlleppeyHill stationBeachesCruisesBackwatersNatureHouseboatRomanticSightseeingBudget
# ...

# %%
ratings = []

for x in soup.find_all("ul", attrs={"class":"clearfix"}):
    ratings.append(x.text.strip() if x else np.nan)

for r in ratings:
    print(r)
# Out:
# Munnar (2D)Alleppey (2D)
# Kochi (1D)Munnar (3D)
# Munnar (2D)Thekkady (1D)Alleppey (1D)Kochi (2D)
# Cochin (1D)Munnar (3D)
# Kochi (2D)
# Wayanad (3D)
# Munnar (2D)Alleppey (2D)
# Munnar (2D)Thekkady (1D)Alleppey (2D)
# Alleppey (2D)
# Munnar (2D)Thekkady (1D)Alleppey (2D)
# Alleppey (3D)
# Munnar (3D)
# Munnar (2D)Thekkady (1D)Alleppey (1D)Kochi (2D)
# Munnar (1D)Alleppey (2D)
# Munnar (1D)Thekkady (1D)Alleppey (2D)
# Athirapally (2D)Munnar (2D)Alleppey (1D)Kovalam (1D)Trivandrum (2D)
# Munnar (2D)Thekkady (2D)
# Kumarakom (1D)Thekkady (1D)Munnar (3D)
# Munnar (2D)Alleppey (2D)
# Munnar (1D)Thekkady (1D)Kochi (2D)

# %%
travel = []

for x in soup.find_all("div", attrs={"class":"col-12 p8 pt0"}):
    travel.append(x.text.strip() if x else np.nan)

for t in travel:
    print(t)
# Out:
# Alleppey-Munnar Kerala Weekend Tour Please deselect at least one item. Only 3 are allowed. Add To Compare4 Days & 3 Nights CustomizableStarting from:24% OffExact prices may vary based on availability.â¹ 13,020/-â¹ 17,132/-Per Person on twin sharingSpice PlantationsHill stationHouseboat StayCruisesEcho PointAdventureTea MuseumNatureBest sellersWaterfallBudgetHotel included in package: 3 Star4 Star5 StarCities: Munnar (2D)Alleppey (2D)Looking for a short break thatâs fun, relaxing and a bit different? This 3 Nights....
# Charismatic Kochi Tour PackagePlease deselect at least one item. Only 3 are allowed. Add To Compare4 Days & 3 Nights CustomizableStarting from:9% OffExact prices may vary based on availability.â¹ 15,000/-â¹ 16,484/-Per Person on twin sharingWaterfallsAdventureNatureShoppingWildlifeCulturalBudgetHotel included in package: 3 StarCities: Kochi (1D)Munnar (3D)Kerala is one of the most loved holiday destinations in India, and Kochi is the perfect....
# ...

# %%
p=[]
for x in soup.find_all('p',attrs={'class':"sfc3 m0 f20 fw9 priceVal at_newprice"}):
    p.append(x.text if x else np.nan)
p
# Out:
# ['â\x82¹ 13,020/-â\x82¹ 17,132/-',
#  'â\x82¹ 15,000/-â\x82¹ 16,484/-',
#  'â\x82¹ 22,000/-â\x82¹ 24,444/-',
#  'â\x82¹ 14,571/-â\x82¹ 16,190/-',
#  'â\x82¹ 4,800/-â\x82¹ 5,275/-',
#  'â\x82¹ 8,500/-â\x82¹ 8,947/-',
#  'â\x82¹ 15,000/-â\x82¹ 16,484/-',
#  'â\x82¹ 19,040/-â\x82¹ 26,478/-',
#  'â\x82¹ 5,000/-â\x82¹ 5,495/-',
#  'â\x82¹ 20,048/-â\x82¹ 24,604/-',
#  'â\x82¹ 7,840/-â\x82¹ 8,615/-',
#  'â\x82¹ 6,000/-â\x82¹ 6,593/-',
#  'â\x82¹ 24,279/-â\x82¹ 29,674/-',
#  'â\x82¹ 9,092/-â\x82¹ 10,102/-',
#  'â\x82¹ 14,000/-â\x82¹ 15,909/-',
#  'â\x82¹ 28,123/-â\x82¹ 30,904/-',
#  'â\x82¹ 13,167/-â\x82¹ 18,434/-',
#  'â\x82¹ 15,624/-â\x82¹ 17,360/-',
#  'â\x82¹ 12,880/-â\x82¹ 16,269/-',
#  'â\x82¹ 11,760/-â\x82¹ 13,213/-']

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time

Name = [] 

stay = []

location = []

discount = []

pagenum = []

Tags = []

Price = []
total_time = time.time()
for i in range(1, 62): 

    start_time = time.time()

    URL = f"https://traveltriangle.com/tour-packages/kerala?travelmonth=May%2C%202026={i}"

    page = requests.get(URL)

    soup = BeautifulSoup(page.text, "html.parser")

    for x in soup.find_all('div', attrs={'class':'col-12 p8 pt0'}):

        name_tag = x.find('p', attrs={"class":"col-md-12 pl0 fw9 m0 f16 pfc3 at_packageName"})

        stay_tag = x.find('span', attrs={'class':'iblock sfc6'})   # discounted price

        location_tag = x.find('ul', attrs={'class':'clearfix package-cities-list at_packagecity_list'})

        discount_tag = x.find('span', attrs={'class':'f12 fw4 pt2 pb2 pl8 pr8 radius20 pbc1 sfcw at_discount_label'})

        Price_tag = x.find('p', attrs={'class':'sfc3 m0 f20 fw9 priceVal at_newprice'})

        Tags_tag = x.find('ul',attrs={'class':'package-tags at_package_tags'})

        Name.append(name_tag.text.strip() if name_tag else np.nan)

        stay.append(stay_tag.text.strip() if stay_tag else np.nan)

        location.append(location_tag.text.strip() if location_tag else np.nan)

        discount.append(discount_tag.text.strip() if discount_tag else np.nan)

        Price.append(Price_tag.text.strip() if Price_tag else np.nan)

        Tags.append(Tags_tag.text.strip() if Tags_tag else np.nan)

        pagenum.append(i)

    print(f'Page {i} completed in {time.time()-start_time:.2f} seconds')

print("Total Time Completed in seconds", str(time.time()-total_time))
# Out:
# Page 1 completed in 10.77 seconds
# Page 2 completed in 3.52 seconds
# Page 3 completed in 4.31 seconds
# Page 4 completed in 3.27 seconds
# Page 5 completed in 2.91 seconds
# Page 6 completed in 3.82 seconds
# Page 7 completed in 3.86 seconds
# Page 8 completed in 3.37 seconds
# Page 9 completed in 5.03 seconds
# Page 10 completed in 3.43 seconds
# Page 11 completed in 3.60 seconds
# Page 12 completed in 4.17 seconds
# Page 13 completed in 3.11 seconds
# Page 14 completed in 3.51 seconds
# Page 15 completed in 3.90 seconds
# Page 16 completed in 5.06 seconds
# Page 17 completed in 3.98 seconds
# Page 18 completed in 5.26 seconds
# Page 19 completed in 4.05 seconds
# Page 20 completed in 4.14 seconds
# Page 21 completed in 3.34 seconds
# Page 22 completed in 4.14 seconds
# Page 23 completed in 3.61 seconds
# Page 24 completed in 4.28 seconds
# Page 25 completed in 2.95 seconds
# Page 26 completed in 3.55 seconds
# Page 27 completed in 4.20 seconds
# Page 28 completed in 4.33 seconds
# ...

# %%
df = pd.DataFrame({
    "Name": Name,
    "Stay": stay,
    "Location": location,
    "Discount": discount,
    "Price": Price,
    "Tags": Tags,
    "Page Number": pagenum})

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location Discount  \
# ...

# %%
df["discount_price"] =( df["Price"].astype(str).str.findall(r"\d{1,3}(?:,\d{2})*,\d{3}").str[0].str.replace(",","").astype(int))

# %%
df["original_price"] =( df["Price"].astype(str).str.findall(r"\d{1,3}(?:,\d{2})*,\d{3}").str[1].str.replace(",","").astype(int))

# %%
df["Discount_percentage"] = (df["Discount"].astype(str).str.extract(r"(\d+)").astype(float))

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location Discount  \
# ...

# %%
df.drop(columns=["Price","Page Number","Discount"],inplace=True)

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location  \
# ...

# %%
df["Locations_List"] = df["Location"].str.findall(r"[A-Za-z ]+(?=\s*\(\d+D\))")

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location  \
# ...

# %%
df["Total_Days"] = (df["Location"].str.findall(r"\((\d+)D\)").apply(lambda x: sum(map(int, x))))

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location  \
# ...

# %%
df["No_of_Locations"] = df["Locations_List"].str.len()

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location  \
# ...

# %%
df["Tags_List"] = df["Tags"].str.findall("[A-Z][a-z]+(?:\s[a-z]+)*(?:\s[A-Z][a-z]+)*")

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location  \
# ...

# %%
df.drop(columns="Tags",inplace=True)

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
# ...

# %%
df.head()
# Out:
#                                                 Name               Stay  \
# 0                Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                     Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2  Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3        Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                       Mesmerizing Getaway To Kochi  2 Days & 1 Nights
#
#                                           Location  discount_price  \
# 0                         Munnar (2D)Alleppey (2D)           13020
# 1                            Kochi (1D)Munnar (3D)           15000
# 2  Munnar (2D)Thekkady (1D)Alleppey (1D)Kochi (2D)           22000
# 3                           Cochin (1D)Munnar (3D)           14571
# 4                                       Kochi (2D)            4800
#
#    original_price  Discount_percentage  \
# 0           17132                 24.0
# 1           16484                  9.0
# ...

# %%
s=df.explode('Locations_List').explode('Tags_List')
s
# Out:
#                                         Name               Stay  \
# 0        Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 0        Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 0        Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 0        Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 0        Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# ...                                      ...                ...
# 1219  Visit Kerala And See Astounding Places  4 Days & 3 Nights
# 1219  Visit Kerala And See Astounding Places  4 Days & 3 Nights
# 1219  Visit Kerala And See Astounding Places  4 Days & 3 Nights
# 1219  Visit Kerala And See Astounding Places  4 Days & 3 Nights
# 1219  Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                 Location  discount_price  original_price  \
# 0               Munnar (2D)Alleppey (2D)           13020           17132
# ...

# %%
s.drop(columns=['Location','Stay'],inplace=True)

# %%
s.reset_index(drop=True).to_csv('clean.csv', index=False)

# %%
df=pd.read_csv("clean.csv")
df
# Out:
#                                          Name  discount_price  original_price  \
# 0         Alleppey-Munnar Kerala Weekend Tour           13020           17132
# 1         Alleppey-Munnar Kerala Weekend Tour           13020           17132
# 2         Alleppey-Munnar Kerala Weekend Tour           13020           17132
# 3         Alleppey-Munnar Kerala Weekend Tour           13020           17132
# 4         Alleppey-Munnar Kerala Weekend Tour           13020           17132
# ...                                       ...             ...             ...
# 26774  Visit Kerala And See Astounding Places           11760           13213
# 26775  Visit Kerala And See Astounding Places           11760           13213
# 26776  Visit Kerala And See Astounding Places           11760           13213
# 26777  Visit Kerala And See Astounding Places           11760           13213
# 26778  Visit Kerala And See Astounding Places           11760           13213
#
# ...

# %%
df.shape
# Out:
# (26779, 8)

# %% [markdown]
# # Outliers

# %%
num = df.select_dtypes(include=['int64', 'float64']).columns

# %%
for col in num:
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(26340)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Name                   0
# discount_price         0
# original_price         0
# Discount_percentage    0
# Locations_List         0
# Total_Days             0
# No_of_Locations        0
# Tags_List              0
# dtype: int64

# %%
cat=df.select_dtypes(include='object').columns
print(cat)
# Out:
# Index(['Name', 'Locations_List', 'Tags_List'], dtype='object')

# %%
num = df.select_dtypes(include=['int64', 'float64']).columns
print(num)
# Out:
# Index(['discount_price', 'original_price', 'Discount_percentage', 'Total_Days',
#        'No_of_Locations'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 439 entries, 0 to 438
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 439 non-null    object
#  1   discount_price       439 non-null    int64
#  2   original_price       439 non-null    int64
#  3   Discount_percentage  439 non-null    float64
#  4   Locations_List       439 non-null    object
#  5   Total_Days           439 non-null    int64
#  6   No_of_Locations      439 non-null    int64
#  7   Tags_List            439 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 30.9+ KB

# %% [markdown]
# # Univariate Analysis (Numerical)

# %% [markdown]
# # Histogram + KDE

# %%
sns.histplot(df['discount_price'], kde=True)
plt.title("Distribution of Discount Prices")
plt.show()

# %% [raw]
# Insights:
# Most tour packages are priced in the mid-range, suitable for budget and family travelers.
# A slight right skew indicates premium packages exist but are fewer.

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x='Total_Days', data=df)
plt.title('Trip Duration Distribution')
plt.show()

# %% [raw]
# Insights
# Most trips last 3–5 days, showing preference for short vacations.
# Longer trips are less common and cater(food & drinks) to extended-stay travelers.

# %% [markdown]
# # categorical

# %%
df['Locations_List'].value_counts().plot(
    kind='pie',
    autopct='%1.0f%%',
    startangle=90,
    textprops={'rotation': 45}
)
plt.title('Distribution of Location Lists')
plt.ylabel('')
plt.show()

# %% [raw]
# Insight:
# Munnar dominates the dataset, accounting for roughly one-third of all tour packages, making it the most popular destination.
# Alleppey and Thekkady together contribute a significant share, indicating strong tourist interest in backwaters and wildlife destinations.

# %% [markdown]
# # Bar Plot

# %%
df['Tags_List'].value_counts().head(10).plot(kind='barh')
plt.title('Top Travel Tags')
plt.xlabel('Count')
plt.show()

# %% [raw]
# Insights:
# Tags such as Nature, Hill Station, and Family dominate the dataset.
# Kerala is primarily marketed as a nature-focused and family-friendly destination.

# %% [markdown]
# # Bivariate

# %% [markdown]
# # Numerical vs Numerical

# %% [markdown]
# # Scatter plot

# %%
df[['No_of_Locations', 'discount_price']].corr()
# Out:
#                  No_of_Locations  discount_price
# No_of_Locations         1.000000        0.925121
# discount_price          0.925121        1.000000

# %%
sns.scatterplot(x='No_of_Locations', y='discount_price', data=df)
plt.title('Number of Locations vs Discount Price')
plt.show()

# %% [raw]
# Insight
# Travel packages that include more locations tend to have higher discounted prices.

# %%
sns.regplot(
    x='No_of_Locations',
    y='discount_price',
    data=df,
    scatter_kws={'alpha': 0.7},
    line_kws={'color': 'red'}
)

plt.title('Number of Locations vs Discount Price')
plt.show()

# %% [raw]
# The scatter plot with trend line shows a strong positive linear relationship between number of locations and discounted price, confirming that packages covering more locations are priced higher even after discounts.
# Correlation 0.92 + upward line = very strong relationship

# %% [markdown]
# # LineChart

# %%
avg_price_days = df.groupby('Total_Days')['discount_price'].mean()
plt.plot(avg_price_days.index, avg_price_days.values, marker='o')
plt.xlabel('Total Days')
plt.ylabel('Average Discount Price')
plt.title('Average Price Trend by Trip Duration')
plt.show()

# %% [raw]
# Insight:
# Average price increases with trip duration.
# Longer itineraries tend to be more expensive.

# %% [markdown]
# # Catgorical vs Numerical

# %% [markdown]
# # Box plot

# %%
df.columns
# Out:
# Index(['Name', 'discount_price', 'original_price', 'Discount_percentage',
#        'Locations_List', 'Total_Days', 'No_of_Locations', 'Tags_List'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(
    x='Locations_List',
    y='Discount_percentage',
    data=df
)
plt.xticks(rotation=45)
plt.title('Location vs Discount Price')
plt.show()

# %% [raw]
# Insights:
# Munnar, Alleppey, and Thekkady show higher median discount percentages and wider variability, indicating more aggressive and varied discounting in these popular tourist locations.
# Kochi has a lower and tightly clustered discount percentage, suggesting more consistent and moderate discounts with fewer extreme offers.
# Locations such as Wayanad, Athirapally, Kovalam, Trivandrum, and Kumarakom exhibit almost fixed discount values, implying standardized or flat discount policies.
# The presence of outliers (e.g., in Kochi) indicates occasional promotional or special discount offers beyond the usual range.

# %% [markdown]
# # Violin Plot

# %%
top_tags = df['Tags_List'].value_counts().head(6).index
tag_df = df[df['Tags_List'].isin(top_tags)]

# %%
sns.violinplot(
    x='Tags_List',
    y='discount_price',
    data=tag_df
)
plt.title('Discount Price Distribution by Travel Tag')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Insights
# Premium experience tags such as Cruises and Sightseeing show higher median prices and wider price distributions, indicating premium pricing and greater variability.

# %% [markdown]
# # Categorical vs Catgorical

# %% [markdown]
# # Heat Map

# %%
stack = pd.crosstab(df['Locations_List'], df['No_of_Locations'])

stack.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Stacked Bar: Location vs Number of Locations')
plt.show()

# %% [raw]
# Insight:
# Munnar and Alleppey have the highest number of tour packages, indicating they are the most popular and frequently included destinations.

# %% [markdown]
# # Count Plot

# %% [markdown]
# # Location vs Top 5 Tags

# %%
top_5_tags = df['Tags_List'].value_counts().head(5).index
df_top_tags = df[df['Tags_List'].isin(top_5_tags)]

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.countplot(
    x='Locations_List',
    hue='Tags_List',
    data=df_top_tags
)

plt.xticks(rotation=45)
plt.xlabel('Location')
plt.ylabel('Number of Packages')
plt.title('Location vs Top 5 Travel Tags')
plt.legend(title='Tags')
plt.show()

# %% [raw]
# Insights
# The top 5 travel tags are unevenly distributed across locations, showing location-specific travel themes.
# Popular destinations offer multiple dominant tags, indicating diversified tour experiences.

# %% [markdown]
# # MultiVariate

# %%
corr = df[['discount_price','original_price','Discount_percentage',
           'Total_Days','No_of_Locations']].corr()

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [raw]
# Insights:
# Strong correlation between original price and discount price confirms pricing consistency.
# Number of locations and days moderately impact pricing, showing experience-driven costs.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(
    df['Total_Days'],
    df['discount_price'],
    s=df['No_of_Locations'] * 40,   # bubble size
    c=df['Discount_percentage'],   # color intensity
    alpha=0.6)
plt.colorbar(label='Discount Percentage')
plt.xlabel('Total Days')
plt.ylabel('Discount Price')
plt.title('Bubble Chart: Price vs Duration vs Locations')

plt.show()

# %% [raw]
# Insights:
# Tour packages with more days and locations tend to have higher prices, confirming experience-based pricing.
# Higher discounts are mostly offered on longer and multi-location packages, likely to attract travelers for extended stays.
